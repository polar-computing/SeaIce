# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['i0']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
from scipy import misc
from sklearn import mixture
from matplotlib import pyplot as plt

# %% [markdown]
# Load example image

# %%
filePath = "C:\\Users\\apbarret\\xsede16_data\\xin_data\\072610_00104.jpg"
#load image
img = misc.imread(filePath)
img.shape
# Out:
# (750L, 1000L, 3L)

# %% [markdown]
# Display raw image

# %%
i0=0
i1=150
j0=300
j1=500
fig0 = plt.figure(figsize=(7,7))
plt.imshow(img[i0:i1,j0:j1,:])

# %%
pixels = []
              
idx = np.random.choice(img.shape[0],size=700,replace=False)
for ii in idx:
    pixels.append(img[ii,ii,:])
    
shape(pixels)
# Out:
# (700L, 3L)

# %%
def image_rgb_histogram(img, means, bins=50, figsize=(7,10)):

    # Convert to a numpy array
    # Expects a numpy array but also deals with a list
    ndimg = np.asarray(img)
    
    # Check that img is greater than 1D
    if ((ndimg.ndim != 2) and (ndimg.ndim != 3)):
        print "% image_rgb_histogram: expects img to be 2D or 3D"
        return
    
    # Extract rgb info
    #  - reshape to n by 3 array
    if (ndimg.ndim == 3):
        tdimg = ndimg.reshape(ndimg.shape[0]*ndimg.shape[1],-1)
    else:
        tdimg = ndimg
        
    r = tdimg[:,0]
    g = tdimg[:,1]
    b = tdimg[:,2]
    
    fig, ax = plt.subplots(3, sharex=True, sharey=True, figsize=figsize)
    ax[0].set_xlim(0,255)
    ax[0].set_ylim(0,0.035)
    n0, bins0, patches0 = ax[0].hist(r, bins=bins, normed=1, facecolor='red', alpha=0.75)
    n1, bins1, patches1 = ax[1].hist(g, bins=bins, normed=1, facecolor='green', alpha=0.75)
    n2, bins2, patches2 = ax[2].hist(b, bins=bins, normed=1, facecolor='blue', alpha=0.75)

    if (size(means) > 1):
        for mean in means:
            for axis in ax:
                axis.axvline(x=mean, color='k', linewidth=2.)
    elif (size(means) == 1):
        for axis in ax:
            axis.axvline(x=means, color='k', linewidth=2.)
        
    fig.subplots_adjust(hspace=0)

# %%
image_rgb_histogram(img, [20,150])

# %%
#print img[:,:,0].min(), img[:,:,0].max(), img[:,:,0].mean()
x0 = img[i0:i1,j0:j1,0].flatten()
x1 = img[i0:i1,j0:j1,1].flatten()
x2 = img[i0:i1,j0:j1,2].flatten()
fig, ax = plt.subplots(3, sharex=True, sharey=True, figsize=(7,10))
ax[0].set_xlim(0,255)
ax[0].set_ylim(0,0.035)
n0, bins0, patches0 = ax[0].hist(x0, bins=50, normed=1, facecolor='red', alpha=0.75)
n1, bins1, patches1 = ax[1].hist(x1, bins=50, normed=1, facecolor='green', alpha=0.75)
n2, bins2, patches2 = ax[2].hist(x2, bins=50, normed=1, facecolor='blue', alpha=0.75)
fig.subplots_adjust(hspace=0)
plt.show()

# %%
# Out:
# Help on package numpy:
#
# NAME
#     numpy
#
# FILE
#     c:\users\apbarret\anaconda\lib\site-packages\numpy\__init__.py
#
# DESCRIPTION
#     NumPy
#     =====
#
#     Provides
#       1. An array object of arbitrary homogeneous items
#       2. Fast mathematical operations over arrays
#       3. Linear Algebra, Fourier Transforms, Random Number Generation
#
#     How to use the documentation
#     ----------------------------
#     Documentation is available in two forms: docstrings provided
#     with the code, and a loose standing reference guide, available from
#     `the NumPy homepage <http://www.scipy.org>`_.
#
#     We recommend exploring the docstrings using
#     `IPython <http://ipython.scipy.org>`_, an advanced Python shell with
#     TAB-completion and introspection capabilities.  See below for further
#     instructions.
#
#     The docstring examples assume that `numpy` has been imported as `np`::
#
#       >>> import numpy as np
#
# ...
